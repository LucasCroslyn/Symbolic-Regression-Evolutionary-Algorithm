# %%
import SymRegFunctions

# %%
data = SymRegFunctions.get_data("d1.csv")
independent_variables = data[:, :-1]
dependent_variables = data[:, -1]
best, toolbox = SymRegFunctions.symReg(independent_variables, dependent_variables, n_gen=50, n_pop=100)
# Out:
#    	      	                       fitness                        	                 size
#    	      	------------------------------------------------------	--------------------------------------
# gen	nevals	Avg        	Max        	Min    	gen	nevals	Avg 	Max	Min	gen	nevals
# 0  	100   	2.54704e+06	2.48259e+08	5829.38	0  	100   	5.01	14 	2  	0  	100
# 1  	54    	16632.9    	117276     	5829.38	1  	54    	4.78	14 	2  	1  	54
# 2  	59    	620815     	5.85744e+07	5829.38	2  	59    	4.5 	8  	3  	2  	59
# 3  	46    	6345.11    	18562.3    	5829.38	3  	46    	3.06	6  	3  	3  	46
# 4  	66    	6165.51    	11817.3    	5829.38	4  	66    	3   	3  	3  	4  	66
# 5  	54    	6110.21    	11817.3    	5829.38	5  	54    	3   	3  	3  	5  	54
# 6  	59    	6328.21    	11756.1    	5829.38	6  	59    	3   	3  	3  	6  	59
# 7  	61    	6105.18    	11696.8    	5829.38	7  	61    	3   	3  	3  	7  	61
# 8  	40    	6170.29    	11756.1    	5829.38	8  	40    	3   	3  	3  	8  	40
# ...

# %%
import TypedFunctions

# %%
data = TypedFunctions.get_data_typed("iris.csv")
best, toolbox = TypedFunctions.typed_reg(data, n_gen=100, n_pop=200)

# Warning about class "Individual" comes from running the SymRegas it also has the creator function that makes the classes for the population
# Out:
# d:\CodingProblems\.conda\lib\site-packages\deap\creator.py:185: RuntimeWarning: A class named 'Individual' has already been created and it will be overwritten. Consider deleting previous creation of that class or rename it.
#   warnings.warn("A class named '{0}' has already been created and it "
#    	      	               fitness                	                 size
#    	      	--------------------------------------	--------------------------------------
# gen	nevals	Avg  	Max	Min	gen	nevals	Avg   	Max	Min	gen	nevals
# 0  	200   	50.13	100	0  	0  	200   	11.715	34 	4  	0  	200
# 1  	151   	52.33	100	50 	1  	151   	10.575	40 	1  	1  	151
# 2  	138   	62.95	100	0  	2  	138   	11.78 	37 	4  	2  	138
# 3  	141   	83.41	100	0  	3  	141   	13.265	25 	4  	3  	141
# 4  	153   	88.225	100	46 	4  	153   	13.8  	28 	9  	4  	153
# 5  	150   	87.68 	100	21 	5  	150   	14.035	28 	9  	5  	150
# 6  	149   	90    	100	50 	6  	149   	13.93 	26 	4  	6  	149
# ...
